# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv("GoldPrice.csv")
df
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
# Convert 'Date' column to datetime format  
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Set 'Date' as the index  
df.set_index('Date', inplace=True)

# %%
# Display the first few rows to check the changes  
print(df.head())
# Out:
#                     SPX        GLD        USO     SLV   EUR/USD
# Date
# 2008-01-02  1447.160034  84.860001  78.470001  15.180  1.471692
# 2008-01-03  1447.160034  85.570000  78.370003  15.285  1.474491
# 2008-01-04  1411.630005  85.129997  77.309998  15.167  1.475492
# 2008-01-07  1416.180054  84.769997  75.500000  15.053  1.468299
# 2008-01-08  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
# Display first and last five rows
print(df.head())
# Out:
#                     SPX        GLD        USO     SLV   EUR/USD
# Date
# 2008-01-02  1447.160034  84.860001  78.470001  15.180  1.471692
# 2008-01-03  1447.160034  85.570000  78.370003  15.285  1.474491
# 2008-01-04  1411.630005  85.129997  77.309998  15.167  1.475492
# 2008-01-07  1416.180054  84.769997  75.500000  15.053  1.468299
# 2008-01-08  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
print(df.tail())
# Out:
#                     SPX         GLD      USO      SLV   EUR/USD
# Date
# 2018-05-08  2671.919922  124.589996  14.0600  15.5100  1.186789
# 2018-05-09  2697.790039  124.330002  14.3700  15.5300  1.184722
# 2018-05-10  2723.070068  125.180000  14.4100  15.7400  1.191753
# 2018-05-14  2730.129883  124.489998  14.3800  15.5600  1.193118
# 2018-05-16  2725.780029  122.543800  14.4058  15.4542  1.182033

# %%
# Dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2290 entries, 2008-01-02 to 2018-05-16
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SPX      2290 non-null   float64
#  1   GLD      2290 non-null   float64
#  2   USO      2290 non-null   float64
#  3   SLV      2290 non-null   float64
#  4   EUR/USD  2290 non-null   float64
# dtypes: float64(5)
# memory usage: 107.3 KB

# %%
# Checking for missing values
df.isnull()
# Out:
#               SPX    GLD    USO    SLV  EUR/USD
# Date
# 2008-01-02  False  False  False  False    False
# 2008-01-03  False  False  False  False    False
# 2008-01-04  False  False  False  False    False
# 2008-01-07  False  False  False  False    False
# 2008-01-08  False  False  False  False    False
# ...           ...    ...    ...    ...      ...
# 2018-05-08  False  False  False  False    False
# 2018-05-09  False  False  False  False    False
# 2018-05-10  False  False  False  False    False
# 2018-05-14  False  False  False  False    False
# 2018-05-16  False  False  False  False    False
#
# [2290 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
# Summary statistics
print(df.describe())
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
# Drop non-numeric columns before calculating correlation
df_numeric = df.select_dtypes(include=['number'])

# %%
# Compute correlation matrix
correlation = df_numeric.corr()

# %%
# Correlation values with Gold Price (GLD)
print("Correlation with Gold Prices:\n", correlation['GLD'])
# Out:
# Correlation with Gold Prices:
#  SPX        0.049345
# GLD        1.000000
# USO       -0.186360
# SLV        0.866632
# EUR/USD   -0.024375
# Name: GLD, dtype: float64

# %%
# Distribution of Gold Prices
sns.displot(df['GLD'], color='green', kde=True)
plt.title("Gold Price Distribution")
plt.xlabel("Gold Price")
plt.ylabel("Frequency")
plt.show()

# %%
# Check available column names
print(df.columns)  # Make sure 'Gold Price' or any other correct name exists

# Plotting the gold price trend
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['GLD'], color='blue', linewidth=2)  # Use the correct column name
plt.xlabel("Year")
plt.ylabel("Gold Price")
plt.title("Gold Price Trends Over Time")
plt.grid(True)
plt.show()
# Out:
# Index(['SPX', 'GLD', 'USO', 'SLV', 'EUR/USD'], dtype='object')

# %%
# Plot heatmap
plt.figure(figsize=(8, 8))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f', annot=True, cmap='Blues')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
print("Analysis Completed!")
# Out:
# Analysis Completed!
